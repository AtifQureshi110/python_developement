# %% [markdown]
# <a href="https://colab.research.google.com/github/AtifQureshi110/python_developement/blob/main/Inheritance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Inheritance
#
# - What is inheritance?
# - it is come from real world. such parents and their off springs. meanwhile child class can inheritant all attributes and methods of parent class and has it's own properties. The biggest of benefits of inheritance is that code reusebilty that's why duplication of data can be avoided.
# - Example
# - What gets inherited?

# %%
from PIL import Image

# Open the image file
image = Image.open('/content/drive/MyDrive/OOP/images/inheritance.jpg')

# Show the image
image.show()
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=541x401 at 0x7F152C5EDA50>

# %%
# Example

# parent
class User:

  def __init__(self):
    self.name = 'nitish'
    self.gender = 'male'

  def login(self):
    print('login')

# child
class Student(User):

  def __init__(self):
    self.rollno = 100

  def enroll(self):
    print('enroll into the course')

u = User()
s = Student()
s.login()
s.enroll()

try:
  print(s.name)
except AttributeError:
  print("""AttributeError: 'Student' object has no attribute 'name'\n\n""")
  print('The error is coming b/c both has their individual contractor.\ndue which inheritance does not work properly and student object try to find s.name in it"s own class\n\n')
  print("you can use the parent's construct only when you do not your own constructor")
# Out:
# login
# enroll into the course
# AttributeError: 'Student' object has no attribute 'name'
#
#
# The error is coming b/c both has their individual contractor.
# due which inheritance does not work properly and student object try to find s.name in it"s own class
#
#
# you can use the parent's construct only when you do not your own constructor

# %%
# Example

# parent
class User:

  def __init__(self):
    self.name = 'Atif'
    self.gender = 'male'

  def login(self):
    print('login')

# child
class Student(User):# without constructor
  def enroll(self):
    print('enroll into the course')

u = User()
s = Student()

display(u.name,u.gender,u.login())
print("**************")
display(s.name,s.login(),s.enroll()) # 1st method print than attribut.
# Out:
# login
# 'Atif'
# 'male'
# None
# **************
# login
# enroll into the course
# 'Atif'
# None
# None

# %%
# Class diagram

# %%
from PIL import Image

# Open the image file
image = Image.open('/content/drive/MyDrive/OOP/images/identification_sign_inheri_agg.jpg')

# Show the image
image.show()
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=721x442 at 0x7F152C662E00>

# %% [markdown]
# ##### What gets inherited?
#
# - Constructor
# - Non Private Attributes
# - Non Private Methods

# %%
# constructor example
class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.price = price
        self.brand = brand
        self.camera = camera

    def buy(self): # non private method.
        print ("Buying a phone")

class SmartPhone(Phone):# 1st concept if child does not have it's own constructor than parent's constructor excute automatically.
    pass

s=SmartPhone(20000, "Apple", 13)
s.buy()
# Out:
# Inside phone constructor
# Buying a phone

# %%
# constructor example 2 which same as above but child has it's own constructor.
class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

class SmartPhone(Phone): # 2nd concept if child has it's own constructor than child class constructor run b/c of parent class constructor never run and if try to access parent class attribut than than error will through b/c they are created yet.
    def __init__(self, os, ram):
        self.os = os
        self.ram = ram
        print ("Inside SmartPhone constructor")

s=SmartPhone("Android", 2)
# Out:
# Inside SmartPhone constructor

# %%
# constructor example 2 which same as above but child has it's own constructor.
class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

class SmartPhone(Phone): # 2nd concept if child has it's own constructor than child class constructor run b/c of parent class constructor never run and if try to access parent class variable than error will through b/c they are created yet.
    def __init__(self, os, ram):
        self.os = os
        self.ram = ram
        print ("Inside SmartPhone constructor")

s=SmartPhone("Android", 2)
try:
  s.brand
except AttributeError:
  print("AttributeError: 'SmartPhone' object has no attribute 'brand'\n")
  print("""2nd concept if child has it's own constructor than child class constructor run.
  B/c of that parent class constructor never run and if child try to access parent class variable
  than error will through b/c those variables are not created yet""")
# Out:
# Inside SmartPhone constructor
# AttributeError: 'SmartPhone' object has no attribute 'brand'
#
# 2nd concept if child has it's own constructor than child class constructor run.
#   B/c of that parent class constructor never run and if child try to access parent class variable
#   than error will through b/c those variables are not created yet

# %%
# 3rd concept child can't access private members of the class

class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    #getter
    def show(self):
        print (self.__price)

class SmartPhone(Phone):
    def check(self):
        print(self.__price)

s=SmartPhone(20000, "Apple", 13)
print(s.brand)
try:
  s.check()
except AttributeError:
  print('\nERROR ERROR ERROR...')
  print("""\n'SmartPhone' object has no attribute '_SmartPhone__price
  \n\n b/c child class access every thing of parents but not their [private variables and methods]
  and  price is private variable.\n But public variables can access'""")
# Out:
# Inside phone constructor
# Apple
#
# ERROR ERROR ERROR...
#
# 'SmartPhone' object has no attribute '_SmartPhone__price
#
#
#  b/c child class access every thing of parents but not their [private variables and methods]
#   and  price is private variable.
#  But public variables can access'

# %%
# 3rd concept child can't access private members of the class

class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    #getter
    def show(self):
        print (self.__price)

class SmartPhone(Phone):
    def check(self):
        print(self.__price)

s=SmartPhone(20000, "Apple", 13)
print(s.brand)
try:
  print(s.show())
except AttributeError:
  print('\nERROR ERROR ERROR...')
  print("""\n'SmartPhone' object has no attribute '_SmartPhone__price
  \n\n b/c child class access every thing of parents but not their [private variables and methods]
  and  price is private variable.\n But public variables can access'""")
# Out:
# Inside phone constructor
# Apple
# 20000
# None

# %%
# 3rd concept child can't access private members of the class

class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    #getter
    def __show(self):
        print (self.__price)

class SmartPhone(Phone):
    def check(self):
        print(self.__price)

s=SmartPhone(20000, "Apple", 13)
print(s.brand)
try:
  print(s.__show())
except AttributeError:
  print('\nERROR ERROR ERROR...')
  print("""\n'SmartPhone' object has no attribute '_SmartPhone__show
  \n\n b/c child class access every thing of parents but not their [private variables and methods]
  and  price is private variable.\n But public variables can access'""")
# Out:
# Inside phone constructor
# Apple
#
# ERROR ERROR ERROR...
#
# 'SmartPhone' object has no attribute '_SmartPhone__show
#
#
#  b/c child class access every thing of parents but not their [private variables and methods]
#   and  price is private variable.
#  But public variables can access'

# %%
# 3rd concept child can't access private members of the class

class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    #getter
    def __show(self):
        print (self.__price)

class SmartPhone(Phone):
    def check(self):
        print(self.__price)

s=SmartPhone(20000, "Apple", 13)
print(s.brand)
try:
  s.__show()
except AttributeError:
  print('\nERROR ERROR ERROR...')
  print("""\n'SmartPhone' object has no attribute '_SmartPhone__show
  \n\n b/c child class access every thing of parents but not their [private variables and methods]
  and  price is private variable.\n But public variables can access'""")
# Out:
# Inside phone constructor
# Apple
#
# ERROR ERROR ERROR...
#
# 'SmartPhone' object has no attribute '_SmartPhone__show
#
#
#  b/c child class access every thing of parents but not their [private variables and methods]
#   and  price is private variable.
#  But public variables can access'

# %%
class Parent:

    def __init__(self,num):
        self.__num=num
    # this is getter
    def get_num(self):
        return self.__num

class Child(Parent):

    def show(self):
        print("This is in child class")

son=Child(100)
print(son.get_num())# due to the getter method private can be access in child class.
son.show()
# Out:
# 100
# This is in child class

# %%
class Parent:

    def __init__(self,num):
        self.__num=num

    def get_num(self):
        return self.__num

class Child(Parent):

    def __init__(self,val,num):
        self.__val=val

    def get_val(self):
        return self.__val

son=Child(100,10)
try:
  print("Parent: Num:",son.get_num())
except AttributeError:
  print('ERROR ERROR ERROR ...')
  print('you did not call parent constructor.')
print("Child: Val:",son.get_val())
# Out:
# ERROR ERROR ERROR ...
# you did not call parent constructor.
# Child: Val: 100

# %%
class A:
    def __init__(self):
        self.var1=100

    def display1(self,var1): # var1 and self.var1 are completely different variable they do not any relationship
        print("class A :", self.var1) # it will access the value of self.var1 which is constructor's variable
        print("class A :", var1) # it will access the value of var1 which is function argument.
class B(A):

    def display2(self,var1): # child do not have it's own constructor so parent constructor automatically called.
        print("class B :", self.var1)

obj=B()
obj.display1(200)
# Out:
# class A : 100
# class A : 200

# %%
# Method Overriding
class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    def buy(self):
        print ("Buying a phone")
        print("""
        \nwhen parent and child is called both have methods of same name.
        \nThis concept is called Method Overriding.
        \nwhen parent and child is called both have methods of same name than method of child class always execute.""")

class SmartPhone(Phone): # child do not have it's own constructor so parent constructor automatically called.
    def buy(self):
        print ("Buying a smartphone")
        print("""
        \nwhen parent and child is called both have methods of same name.
        \nThis concept is called Method Overriding.
        \nwhen parent and child is called both have methods of same name than method of child class always execute.""")

s=SmartPhone(20000, "Apple", 13)
s.buy()
# constructor Overriding have same story line as method overridin. Since is also a method so it comes method overriding.
# Out:
# Inside phone constructor
# Buying a smartphone
#
#
# when parent and child is called both have methods of same name.
#
# This concept is called Method Overriding.
#
# when parent and child is called both have methods of same name than method of child class always execute.

# %% [markdown]
# # three key words always ask in oop.
# - self: by using self key word you call parents things easily
# - supper: many question are asked. supper is a way to access the only the methods of parents call.
# - static

# %% [markdown]
# ### Super Keyword

# %%
class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    def buy(self):
        print ("Buying a phone")

class SmartPhone(Phone):
    def buy(self):
        print ("Buying a smartphone")
        # syntax to call parent ka buy method
        # supper key Word is used inside the class and in child class always.
        super().buy()

s=SmartPhone(20000, "Apple", 13)

s.buy()
# Out:
# Inside phone constructor
# Buying a smartphone
# Buying a phone

# %%
# using super outside the class
class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    def buy(self):
        print ("Buying a phone")

class SmartPhone(Phone):
    def buy(self):
        print ("Buying a smartphone")
        # syntax to call parent ka buy method
        super().buy()

s=SmartPhone(20000, "Apple", 13)

s.buy()
# Out:
# Inside phone constructor
# Buying a smartphone
# Buying a phone

# %%
# can super access parent ka data?
# using super outside the class
class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    def buy(self):
        print ("Buying a phone")

class SmartPhone(Phone):
    def buy(self):
        print ("Buying a smartphone")
        # syntax to call parent ka buy method
        try:
          print(super().brand)
        except AttributeError:
          print('\n\nError, Error, Error ...')
          print("AttributeError: 'super' object has no attribute 'brand'")
          print('with help of supper key you can access the only the methods of the parents class not attributs of parents class ')
          print('supper can not be used outside the class')
s=SmartPhone(20000, "Apple", 13)
s.buy()
# Out:
# Inside phone constructor
# Buying a smartphone
#
#
# Error, Error, Error ...
# AttributeError: 'super' object has no attribute 'brand'
# with help of supper key you can access the only the methods of the parents class not attributs of parents class
# supper can not be used outside the class

# %%
# super -> constuctor
class Phone:
    def __init__(self, price, brand, camera): # parent constructor
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

class SmartPhone(Phone):
    def __init__(self, price, brand, camera, os, ram): # child constructor
        print('Inside smartphone constructor')
        super().__init__(price, brand, camera) # child constructor is calling parents constructor to inheritant parent's property
        self.os = os
        self.ram = ram
        print ("Inside smartphone constructor")

s=SmartPhone(20000, "Samsung", 12, "Android", 2)

print(s.os)
print(s.brand)
print(s.ram)
print(s.camera)
# Out:
# Inside smartphone constructor
# Inside phone constructor
# Inside smartphone constructor
# Android
# Samsung
# 2
# 12

# %% [markdown]
# ##### Inheritance in summary
#
# - A class can inherit from another class.
#
# - Inheritance improves code reuse
#
# - Constructor, attributes, methods get inherited to the child class
#
# - The parent has no access to the child class
#
# - Private properties of parent are not accessible directly in child class
#
# - Child class can override the attributes or methods. This is called method overriding
#
# - super() is an inbuilt function which is used to invoke the parent class methods and constructor

# %%
class Parent:

    def __init__(self,num):
      self.__num=num

    def get_num(self):
      return self.__num

class Child(Parent):

    def __init__(self,num,val):
      super().__init__(num)
      self.__val=val

    def get_val(self):
      return self.__val

son=Child(100,200)
print(son.get_num())
print(son.get_val())
# Out:
# 100
# 200

# %%
class Parent:
    def __init__(self):
        self.num=100

class Child(Parent):

    def __init__(self):
        super().__init__()
        self.var=200

    def show(self):
        print(self.num)
        print(self.var)

son=Child()
son.show()
# Out:
# 100
# 200

# %%
class Parent:
    def __init__(self):
        self.__num=100

    def show(self):
        print("Parent:",self.__num)

class Child(Parent):
    def __init__(self):
        super().__init__()
        self.__var=10

    def show(self):
        print("Child:",self.__var)

obj=Child()
obj.show()
# Out:
# Child: 10

# %%
class Parent:
    def __init__(self):
        self.__num=100

    def show(self):
        print("Parent:",self.__num)

class Child(Parent):
    def __init__(self):
        super().__init__()
        self.__var=10

    def show(self):
        print("Child:",self.__var)

obj=Child()
obj.show()
# Out:
# Child: 10

# %% [markdown]
# ### Types of Inheritance
#
# - Single Inheritance
# - Multilevel Inheritance
# - Hierarchical Inheritance
# - Multiple Inheritance(Diamond Problem)
# - Hybrid Inheritance

# %%
from PIL import Image

# Open the image file
image = Image.open('/content/drive/MyDrive/OOP/images/type inheri.jpg')

# Show the image
image.show()
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=618x362 at 0x7F20EC423A90>

# %%
image = Image.open('/content/drive/MyDrive/OOP/images/multiple inher.jpg')
# Show the image
image.show()
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=190x220 at 0x7F20EC423BE0>

# %%
image = Image.open('/content/drive/MyDrive/OOP/images/hiberide.jpg')
# Show the image
image.show()
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=270x232 at 0x7F20EC422FE0>

# %%
# single inheritance
class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    def buy(self):
        print ("Buying a phone")

class SmartPhone(Phone):
    pass
#b = Phone(1000,"Apple","13px")
s = SmartPhone(1000,"Apple","13px")
print(s.brand)
print(s.camera)
print(s.buy())
#print(s.buy())

SmartPhone(1000,"Apple","13px").buy()
# Out:
# Inside phone constructor
# Apple
# 13px
# Buying a phone
# None
# Inside phone constructor
# Buying a phone

# %%
# multilevel
class Product:
    def review(self):
        print ("Product customer review")

class Phone(Product):
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    def buy(self):
        print ("Buying a phone")

class SmartPhone(Phone):
    pass

s=SmartPhone(20000, "Apple", 12) # this child class

s.buy() # this is function of parent class called by using child object.
s.review()# this is function of grand parent class called by using child object.
# this is multiple level class which is inheritanting properties it's parents classes
# Out:
# Inside phone constructor
# Buying a phone
# Product customer review

# %%
# Hierarchical
class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    def buy(self):
        print ("Buying a phone")

class SmartPhone(Phone):# inheritance
    pass

class FeaturePhone(Phone): # inheritance
    pass

SmartPhone(1000,"Apple","13px").buy()
FeaturePhone(10,"Lava","1px").buy()
# Out:
# Inside phone constructor
# Buying a phone
# Inside phone constructor
# Buying a phone

# %%
# Multiple
class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    def buy(self):
        print ("Buying a phone")

class Product:
    def review(self):
        print ("Customer review")

class SmartPhone(Phone, Product):# inheritance two classes is called multiple inheritance
    pass

s=SmartPhone(20000, "Apple", 12)

s.buy()
s.review()
# Out:
# Inside phone constructor
# Buying a phone
# Customer review

# %%
# the diamond problem
# https://stackoverflow.com/questions/56361048/what-is-the-diamond-problem-in-python-and-why-its-not-appear-in-python2
"""
 Phone and Product both are classes as parent meanwhile both have buy method so which one the SmartPhone(child class)
 it would inheritant that one which it inheritants 1st among the others
 this method is called Method resolution order (MRO)
 such as SmartPhone(Phone, Product) here it gives preference to Phone class
 SmartPhone(Product, Phone)  here it gives preference to Product class
 """
class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    def buy(self):
        print ("Buying a phone")

class Product:
    def buy(self):
        print ("Product buy method")

# Method resolution order (MRO)
class SmartPhone(Phone,Product):
    pass

s=SmartPhone(20000, "Apple", 12)

s.buy()
# Out:
# Inside phone constructor
# Buying a phone

# %%
class A:

    def m1(self):
        return 20

class B(A):

    def m1(self):
        return 30

    def m2(self):
        return 40

class C(B):

    def m2(self):
        return 20
obj1=A()
obj2=B()
obj3=C()
print(obj1.m1() + obj3.m1()+ obj3.m2())
# Out:
# 70

# %%
class A:

    def m1(self):
        return 20

class B(A):

    def m1(self):
        val=super().m1()+30
        return val

class C(B):

    def m1(self):
        val=self.m1()+20
        return val
obj=C()
try :
  print(obj.m1())
except RecursionError:
  print('\n\nERROR ERROR ERROR ...')
  print('RecursionError: maximum recursion depth exceeded')
  print('the error indicates that function call itself again...\npython realize that it infinit loop')
# Out:
# ERROR ERROR ERROR ...
# RecursionError: maximum recursion depth exceeded
# the error indicates that function call itself again...
# python realize that it infinit loop
